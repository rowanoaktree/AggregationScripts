# %%
#Adding info field:
expert_orig = "info": {
    "description": "Dataset of drone images of waterfowl with object-based annotations by species. UAS imagery was collected in fall/winter 2018 of overwintering migratory waterfowl at Bosque del Apache using a DJI Mavic Pro 2 / Hasselblad L1D-20c sensor, and at Maxwell NWR using an EBEE+ and Sensefly S.O.D.A. sensor. Annotations generated by fifteen US Fish and Wildlife biologists in 2019 using the Labelbox platform. Individual identifying information has been redacted for privacy purposes.",
    "url": "",
    "version": "1.0",
    "year": 2023,
    "creator": "Rowan Converse",
    "date_created": "2022-04",
    "license": {
        "name": "Attribution 4.0 International (CC BY 4.0)",
        "url": "https://creativecommons.org/licenses/by/4.0/"
    }
}

expert_refined = "info": {
    "description": "Dataset of drone images of waterfowl with object-based annotations by species. UAS imagery was collected in fall/winter 2018 of overwintering migratory waterfowl at Bosque del Apache using a DJI Mavic Pro 2 / Hasselblad L1D-20c sensor, and at Maxwell NWR using an EBEE+ and Sensefly S.O.D.A. sensor. Annotations generated by fifteen US Fish and Wildlife biologists in 2019 using the Labelbox platform. Consensus annotations generated using DBSCAN to cluster annotations, then plurality vote for consensus class ID and median area of all bounding boxes in the cluster (script: url). Annotations believed by DBSCAN to be noise points and annotations where no consensus class ID could be reached were removed.",
    "url": "",
    "version": "1.0",
    "year": 2023,
    "creator": "Rowan Converse",
    "date_created": "2022-04",
    "license": {
        "name": "Attribution 4.0 International (CC BY 4.0)",
        "url": "https://creativecommons.org/licenses/by/4.0/"
    }
}

crowd_orig = "info": {
    "description": "Dataset of drone images of waterfowl with object-based annotations by species. UAS imagery was collected in fall/winter 2018-2022 of overwintering migratory waterfowl at Bosque del Apache NWR, Rio Grande State Park, and the Ladd S Gordon Waterfowl Complex using a DJI Mavic Pro 2 / Hasselblad L1D-20c sensor, and at Maxwell NWR using an EBEE+ and Sensefly S.O.D.A. sensor. Annotations generated by 5,503 volunteers via the Zooniverse participatory science platform. Annotator usernames have been removed.",
    "url": "",
    "version": "1.0",
    "year": 2023,
    "creator": "Rowan Converse",
    "date_created": "2022-04",
    "license": {
        "name": "Attribution 4.0 International (CC BY 4.0)",
        "url": "https://creativecommons.org/licenses/by/4.0/"
    }
}

crowd_refined = "info": {
    "description": "Dataset of drone images of waterfowl with object-based annotations by species. UAS imagery was collected in fall/winter 2018-2022 of overwintering migratory waterfowl at Bosque del Apache NWR, Rio Grande State Park, and the Ladd S Gordon Waterfowl Complex using a DJI Mavic Pro 2 / Hasselblad L1D-20c sensor, and at Maxwell NWR using an EBEE+ and Sensefly S.O.D.A. sensor. Annotations generated by 5,503 volunteers via the Zooniverse participatory science platform. Consensus annotations generated using DBSCAN to cluster annotations, then plurality vote for consensus class ID and median area of all bounding boxes in the cluster (script: url). Annotations believed by DBSCAN to be noise points and annotations where no consensus class ID could be reached were removed.",
    "url": "",
    "version": "1.0",
    "year": 2023,
    "creator": "Rowan Converse",
    "date_created": "2022-04",
    "license": {
        "name": "Attribution 4.0 International (CC BY 4.0)",
        "url": "https://creativecommons.org/licenses/by/4.0/"
    }
}
